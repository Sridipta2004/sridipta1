# %% [markdown]
# <a href="https://colab.research.google.com/github/Sridipta2004/sridipta1/blob/main/machinelearning1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
data={
    'hour_studied':[1,3,4,5,6,7,8,9,10],
    'grade':[19,20,30,40,50,60,70,80,90]
}

# %%
data
# Out:
# {'hour_studied': [1, 3, 4, 5, 6, 7, 8, 9, 10],
#  'grade': [19, 20, 30, 40, 50, 60, 70, 80, 90]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    hour_studied  grade
# 0             1     19
# 1             3     20
# 2             4     30
# 3             5     40
# 4             6     50
# 5             7     60
# 6             8     70
# 7             9     80
# 8            10     90

# %%
plt.scatter(df['hour_studied'], df['grade'])
plt.xlabel('hour_studied')
plt.ylabel('grade')
plt.show()

# %%
x= df[['hour_studied']]
y= df[['grade']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#    hour_studied
# 2             4
# 3             5
# 7             9
# 6             8
# 4             6
# 0             1
# 1             3

# %%
x_test
# Out:
#    hour_studied
# 8            10
# 5             7

# %%
y_train
# Out:
#    grade
# 2     30
# 3     40
# 7     80
# 6     70
# 4     50
# 0     19
# 1     20

# %%
y_test
# Out:
#    grade
# 8     90
# 5     60

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#    hour_studied
# 8            10
# 5             7

# %%
y_test
# Out:
#    grade
# 8     90
# 5     60

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([[84.55487805],
#        [59.5945122 ]])

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 0.0

# %%
rmse=np.sqrt(mse)
